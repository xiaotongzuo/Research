# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
path=('/Users/XT/ResearchApps/Output/Results/')

# %%
bins=np.arange(350.5,357,0.5)
count=[2
,3
,25
,94
,140
,185
,126
,146
,167
,74
,28
,7
,2]
print len(bins),len(count)
# Out:
# 13 13

# %%
width=0.3
plt.bar(bins,count,width,color='black',alpha=0.7)
plt.xlabel('Score/REU')
plt.ylabel('Count')
plt.xticks(bins, bins,rotation=45)
plt.title('M2 Low-Resolution Modeling Efficiency',fontsize=14)
plt.savefig(path+'M2 Low-Resolution Modeling Efficiency.png')

# %%
count2=[2,6
,32
,81
,112
,126
,74
,82
,65
,106
,201
,94
,18
,1]
bins2=np.arange(6,20,1)
print len(count2),len(bins2)
# Out:
# 14 14

# %%
#plt.figure(figsize=(10,8))
plt.bar(bins2,count2,width=0.6,color='black',alpha=0.7)
plt.xlabel('Score/REU')
plt.ylabel('Count')
plt.xticks(bins2, bins2)
plt.title('ACICU Low-Resolution Modeling Efficiency',fontsize=14)
plt.savefig(path+'ACICU Low-Resolution Modeling Efficiency.png')

# %%
score=[]
rmsd=[]
path='/Users/XT/ResearchApps/Output/Results/'
with open(path+'m2_RMSD.csv','r+') as f:
    for line in f.readlines():
        score.append(line.split(',')[1].split()[0]) 
        rmsd.append(line.split(',')[3].split()[0])

# %%
score.remove(score[-1])

# %%
rmsd.remove(rmsd[-1])

# %%
#plt.figure(figsize=(1,1))
plt.plot(rmsd,score,'o',alpha=0.2,c='k')
plt.axis([0,1,340,355])
plt.show()

# %%
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ',fontsize=14)
plt.axis([0,7,-100,-90])

# %%
score2=[]
rmsd2=[]
path='/Users/XT/ResearchApps/Output/Results/'
with open(path+'ACICU_RMSD.csv','r+') as f:
    for line in f.readlines():
        score2.append(line.split(',')[1].split()[0]) 
        rmsd2.append(line.split(',')[3].split()[0])

# %%
plt.plot(rmsd2,score2,'o',alpha=0.2,c='k')
#plt.axis([0,7,0,6])
plt.show()

# %%
fig, ax = plt.subplots()  ###fig = plt.figure(),ax = fig.add_subplot(111)
ax.scatter(np.linspace(-1, 1, 50), np.random.randn(50))
#fig.savefig('yourfilename.png')
